# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

class CustomImageDataGenerator(ImageDataGenerator):
    def __init__(self, cutout_mask_size = 0, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.cutout_mask_size = cutout_mask_size
        
    def cutout(self, x, y):
        return np.array(list(map(self._cutout, x))), y
    
    def _cutout(self, image_origin):
        # 最後に使うfill()は元の画像を書き換えるので、コピーしておく
        image = np.copy(image_origin)
        mask_value = image.mean()

        h, w, _ = image.shape
        # マスクをかける場所のtop, leftをランダムに決める
        # はみ出すことを許すので、0以上ではなく負の値もとる(最大mask_size // 2はみ出す)
        top = np.random.randint(0 - self.cutout_mask_size // 2, h - self.cutout_mask_size)
        left = np.random.randint(0 - self.cutout_mask_size // 2, w - self.cutout_mask_size)
        bottom = top + self.cutout_mask_size
        right = left + self.cutout_mask_size

        # はみ出した場合の処理
        if top < 0:
            top = 0
        if left < 0:
            left = 0

        # マスク部分の画素値を平均値で埋める
        image[top:bottom, left:right, :].fill(mask_value)
        return image
    
    def flow(self, *args, **kwargs):
        batches = super().flow(*args, **kwargs)
        
        # 拡張処理
        while True:
            batch_x, batch_y = next(batches)
            
            if self.cutout_mask_size > 0:
                result = self.cutout(batch_x, batch_y)
                batch_x, batch_y = result                        
                
            yield (batch_x, batch_y)     

datagen_parameters = {"horizontal_flip": True, "width_shift_range": 0.1, "height_shift_range": 0.1, "cutout_mask_size": 16}
datagen = CustomImageDataGenerator(**datagen_parameters)
datagen_for_test = ImageDataGenerator()

# %%
from tensorflow.keras.layers import Conv2D, Dense, BatchNormalization, Activation, MaxPool2D, GlobalAveragePooling2D, Add, Input, Flatten
from tensorflow.keras import Model
from tensorflow.keras.regularizers import l2

n = 9 # 56 layers
channels = [16, 32, 64]

inputs = Input(shape=(32, 32, 3))
x = Conv2D(channels[0], kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(inputs)
x = BatchNormalization()(x)
x = Activation(tf.nn.relu)(x)

for c in channels:
    for i in range(n):
        subsampling = i == 0 and c > 16
        strides = (2, 2) if subsampling else (1, 1)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", strides=strides, kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        y = BatchNormalization()(y)
        y = Activation(tf.nn.relu)(y)
        y = Conv2D(c, kernel_size=(3, 3), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(y)
        y = BatchNormalization()(y)        
        if subsampling:
            x = Conv2D(c, kernel_size=(1, 1), strides=(2, 2), padding="same", kernel_initializer="he_normal", kernel_regularizer=l2(1e-4))(x)
        x = Add()([x, y])
        x = Activation(tf.nn.relu)(x)

x = GlobalAveragePooling2D()(x)
x = Flatten()(x)
outputs = Dense(10, activation=tf.nn.softmax, kernel_initializer="he_normal")(x)

model = Model(inputs=inputs, outputs=outputs)
model.type = "resnet" + str(6 * n + 2)

# %%
from io import StringIO
import re

with StringIO() as buf:
    model.summary(print_fn=lambda x: buf.write(x + "\n"))
    summary = buf.getvalue()
print(summary)
re1 = re.match(r"(.|\s)*Total params: ", summary)
re2 = re.match(r"(.|\s)*Total params: [\d|,]+", summary)
total_params = summary[re1.end():re2.end()]
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 16)   448         ['input_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_1 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_1[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_2 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  add (Add)                      (None, 32, 32, 16)   0           ['activation_1[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_3 (Activation)      (None, 32, 32, 16)   0           ['add[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_3[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 16)  64          ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_4 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_4[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 32, 32, 16)   0           ['activation_3[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 16)   0           ['add_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_5[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 16)  64          ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_6 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_6[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 16)  64          ['conv2d_19[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 32, 32, 16)   0           ['activation_5[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 16)   0           ['add_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_7[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 16)  64          ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 32, 32, 16)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_8[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 16)  64          ['conv2d_21[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 16)   0           ['activation_7[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 16)   0           ['add_3[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_9[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_10[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 32, 32, 16)   0           ['activation_9[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 16)   0           ['add_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_11[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 32, 32, 16)  64          ['conv2d_25[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 32, 32, 16)   0           ['activation_11[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 16)   0           ['add_5[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_13[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 16)  64          ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_14[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 16)  64          ['conv2d_27[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 32, 16)   0           ['activation_13[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  activation_15 (Activation)     (None, 32, 32, 16)   0           ['add_6[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_15[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_16[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 32, 16)   0           ['activation_15[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_17 (Activation)     (None, 32, 32, 16)   0           ['add_7[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_17[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 16)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 16)   2320        ['activation_18[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 16)  64          ['conv2d_31[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 32, 16)   0           ['activation_17[0][0]',
#                                                                   'batch_normalization_32[0][0]']
#
#  activation_19 (Activation)     (None, 32, 32, 16)   0           ['add_8[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 32)   4640        ['activation_19[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 32)  128         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_20[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 16, 16, 32)   544         ['activation_19[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 32)  128         ['conv2d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 16, 16, 32)   0           ['conv2d_34[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  activation_21 (Activation)     (None, 16, 16, 32)   0           ['add_9[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_21[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 32)  128         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_22[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 32)  128         ['conv2d_36[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 16, 16, 32)   0           ['activation_21[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  activation_23 (Activation)     (None, 16, 16, 32)   0           ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_23[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 32)  128         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_24[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 16, 32)   0           ['activation_23[0][0]',
#                                                                   'batch_normalization_38[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 32)   0           ['add_11[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_25[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 32)  128         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_26[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 16, 16, 32)  128         ['conv2d_40[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 16, 32)   0           ['activation_25[0][0]',
#                                                                   'batch_normalization_40[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 32)   0           ['add_12[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_27[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 16, 16, 32)  128         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_28[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 16, 16, 32)  128         ['conv2d_42[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 16, 32)   0           ['activation_27[0][0]',
#                                                                   'batch_normalization_42[0][0]']
#
#  activation_29 (Activation)     (None, 16, 16, 32)   0           ['add_13[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_29[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 16, 16, 32)  128         ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_30[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 16, 16, 32)  128         ['conv2d_44[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 16, 16, 32)   0           ['activation_29[0][0]',
#                                                                   'batch_normalization_44[0][0]']
#
#  activation_31 (Activation)     (None, 16, 16, 32)   0           ['add_14[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_31[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 16, 16, 32)  128         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_32[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 16, 16, 32)  128         ['conv2d_46[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 16, 16, 32)   0           ['activation_31[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_33 (Activation)     (None, 16, 16, 32)   0           ['add_15[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_33[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 16, 16, 32)  128         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_34[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 16, 16, 32)  128         ['conv2d_48[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 16, 16, 32)   0           ['activation_33[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  activation_35 (Activation)     (None, 16, 16, 32)   0           ['add_16[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_35[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 16, 16, 32)  128         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 16, 16, 32)   0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 16, 16, 32)   9248        ['activation_36[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 16, 16, 32)  128         ['conv2d_50[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 16, 16, 32)   0           ['activation_35[0][0]',
#                                                                   'batch_normalization_50[0][0]']
#
#  activation_37 (Activation)     (None, 16, 16, 32)   0           ['add_17[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 8, 8, 64)     18496       ['activation_37[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 8, 64)    256         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_38[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 8, 8, 64)     2112        ['activation_37[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 8, 8, 64)    256         ['conv2d_52[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 8, 8, 64)     0           ['conv2d_53[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  activation_39 (Activation)     (None, 8, 8, 64)     0           ['add_18[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_39[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 8, 8, 64)    256         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_53[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 8, 8, 64)    256         ['conv2d_55[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 8, 8, 64)     0           ['activation_39[0][0]',
#                                                                   'batch_normalization_54[0][0]']
#
#  activation_41 (Activation)     (None, 8, 8, 64)     0           ['add_19[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_41[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 8, 8, 64)    256         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_55[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_42[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 8, 8, 64)    256         ['conv2d_57[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 8, 8, 64)     0           ['activation_41[0][0]',
#                                                                   'batch_normalization_56[0][0]']
#
#  activation_43 (Activation)     (None, 8, 8, 64)     0           ['add_20[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_43[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 8, 8, 64)    256         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_44[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 8, 8, 64)    256         ['conv2d_59[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 8, 8, 64)     0           ['activation_43[0][0]',
#                                                                   'batch_normalization_58[0][0]']
#
#  activation_45 (Activation)     (None, 8, 8, 64)     0           ['add_21[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_45[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 8, 8, 64)    256         ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_46[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 8, 8, 64)    256         ['conv2d_61[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 8, 8, 64)     0           ['activation_45[0][0]',
#                                                                   'batch_normalization_60[0][0]']
#
#  activation_47 (Activation)     (None, 8, 8, 64)     0           ['add_22[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_47[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 8, 8, 64)    256         ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_61[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_48[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 8, 8, 64)    256         ['conv2d_63[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 8, 8, 64)     0           ['activation_47[0][0]',
#                                                                   'batch_normalization_62[0][0]']
#
#  activation_49 (Activation)     (None, 8, 8, 64)     0           ['add_23[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_49[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 8, 8, 64)    256         ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_50[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 8, 8, 64)    256         ['conv2d_65[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 8, 8, 64)     0           ['activation_49[0][0]',
#                                                                   'batch_normalization_64[0][0]']
#
#  activation_51 (Activation)     (None, 8, 8, 64)     0           ['add_24[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_51[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 8, 8, 64)    256         ['conv2d_66[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_52[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 8, 8, 64)    256         ['conv2d_67[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 8, 8, 64)     0           ['activation_51[0][0]',
#                                                                   'batch_normalization_66[0][0]']
#
#  activation_53 (Activation)     (None, 8, 8, 64)     0           ['add_25[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_53[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 8, 8, 64)    256         ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_54[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 8, 8, 64)    256         ['conv2d_69[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 8, 8, 64)     0           ['activation_53[0][0]',
#                                                                   'batch_normalization_68[0][0]']
#
#  activation_55 (Activation)     (None, 8, 8, 64)     0           ['add_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['activation_55[0][0]']
#  alAveragePooling2D)
#
#  flatten_1 (Flatten)            (None, 64)           0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 10)           650         ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 861,770
# Trainable params: 857,706
# Non-trainable params: 4,064
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam, SGD
# lr = 0.001
# optimizer = Adam(learning_rate=lr)
lr = 0.1
optimizer = SGD(learning_rate=lr, momentum=0.9)
model.compile(optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
from hyperdash import monitor_cell
from hyperdash import Experiment
exp = Experiment("ResNet-for-CIFAR-10-with-Keras")
# Out:
# Unable to detect API key in hyperdash.json or HYPERDASH_API_KEY environment variable
# Unable to communicate with Hyperdash servers
# Leraning rate is controled by epoch.

# %%
from tensorflow.keras.callbacks import Callback
import time

class Hyperdash(Callback):
    def __init__(self, entries, exp):
        super(Hyperdash, self).__init__()
        self.entries = entries
        self.exp = exp

    def on_epoch_end(self, epoch, logs=None):
        for entry in self.entries:
            log = logs.get(entry)            
            if log is not None:
                self.exp.metric(entry, log)

class LearningController(Callback):
    def __init__(self, num_epoch=0, learn_minute=0):
        self.num_epoch = num_epoch
        self.learn_second = learn_minute * 60
        if self.learn_second > 0:
            print("Leraning rate is controled by time.")
        elif self.num_epoch > 0:
            print("Leraning rate is controled by epoch.")
        
    def on_train_begin(self, logs=None):
        if self.learn_second > 0:
            self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        if self.learn_second > 0:
            current_time = time.time()
            if current_time - self.start_time > self.learn_second:
                self.model.stop_training = True
                print("Time is up.")
                return

            if current_time - self.start_time > self.learn_second / 2:
                self.model.optimizer.lr = lr * 0.1            
            if current_time - self.start_time > self.learn_second * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                
        elif self.num_epoch > 0:
            if epoch > self.num_epoch / 2:
                self.model.optimizer.lr = lr * 0.1            
            if epoch > self.num_epoch * 3 / 4:
                self.model.optimizer.lr = lr * 0.01
                    
        print('lr:%.2e' % self.model.optimizer.lr.value())

# %%
num_epoch = 182
learn_minute = 120

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

hyperdash = Hyperdash(["val_loss", "loss", "val_accuracy", "accuracy"], exp)
checkpoint = ModelCheckpoint(filepath = "ResNet-for-CIFAR-10-with-Keras.h5", monitor="val_loss", verbose=1, save_best_only=True)
learning_controller = LearningController(num_epoch)
callbacks = [hyperdash, checkpoint, learning_controller]

# %%
batch_size = 128
number_train = info.splits["train"].num_examples
number_test = info.splits["test"].num_examples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16760\1404572527.py in <module>
#       1 batch_size = 128
# ----> 2 number_train = info.splits["train"].num_examples
#       3 number_test = info.splits["test"].num_examples
#
# NameError: name 'info' is not defined

# %%
import json

exp.param("Model type", model.type)
exp.param("Total params", total_params)
exp.param("Optimizer", optimizer)
exp.param("Leraning rate", lr)
exp.param("Datagen", json.dumps(datagen_parameters))
exp.param("Batch size", batch_size)
exp.param("Number of epoch", num_epoch)
exp.param("Learn minute", learn_minute)

# %%
history = model.fit(datagen.flow(train_x, train_y, batch_size=batch_size), 
                    epochs=num_epoch, 
                    steps_per_epoch=number_train//batch_size, 
                    validation_data=datagen_for_test.flow(test_x, test_y, batch_size=batch_size), 
                    validation_steps=number_test//batch_size,
                    verbose=0,                    
                    callbacks=callbacks)
exp.end()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"], label = 'Train Accuracy')
plt.plot(history.history["val_accuracy"], linestyle = 'dashed', label = 'Test Accuracy')
plt.legend()
plt.show()

# %%
model.evaluate(test_x, test_y)
